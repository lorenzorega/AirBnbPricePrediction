# %%
# !pip install numpy
# !pip install matplotlib
# !pip install keras
# !pip install scipy
# !pip install pandas
# !pip install shapely
# !pip install geopandas
# !pip install textblob
# !pip install statsmodels
# !pip install scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\lorenzo\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\lorenzo\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lorenzo\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\lorenzo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting keras
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
# Successfully installed keras-2.12.0
# Requirement already satisfied: scipy in c:\users\lorenzo\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\lorenzo\anaconda3\lib\site-packages (from scipy) (1.21.5)
# Requirement already satisfied: pandas in c:\users\lorenzo\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\lorenzo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: shapely in c:\users\lorenzo\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy>=1.14 in c:\users\lorenzo\anaconda3\lib\site-packages (from shapely) (1.21.5)
# Requirement already satisfied: geopandas in c:\users\lorenzo\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\lorenzo\anaconda3\lib\site-packages (from geopandas) (3.4.0)
# Requirement already satisfied: packaging in c:\users\lorenzo\anaconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: fiona>=1.8 in c:\users\lorenzo\anaconda3\lib\site-packages (from geopandas) (1.8.22)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: shapely>=1.7 in c:\users\lorenzo\anaconda3\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: munch in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: certifi in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: setuptools in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (61.2.0)
# Requirement already satisfied: click>=4.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: attrs>=17 in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\users\lorenzo\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\lorenzo\anaconda3\lib\site-packages (from click>=4.0->fiona>=1.8->geopandas) (0.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lorenzo\anaconda3\lib\site-packages (from packaging->geopandas) (3.0.4)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: click in c:\users\lorenzo\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lorenzo\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\lorenzo\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.0)
# Requirement already satisfied: joblib in c:\users\lorenzo\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: colorama in c:\users\lorenzo\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Requirement already satisfied: statsmodels in c:\users\lorenzo\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\lorenzo\anaconda3\lib\site-packages (from statsmodels) (1.21.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\lorenzo\anaconda3\lib\site-packages (from statsmodels) (1.7.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\lorenzo\anaconda3\lib\site-packages (from statsmodels) (1.4.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\lorenzo\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\lorenzo\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lorenzo\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lorenzo\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\lorenzo\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\lorenzo\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\lorenzo\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in c:\users\lorenzo\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\lorenzo\anaconda3\lib\site-packages (from scikit-learn) (1.7.3)

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import datetime as dt

# %%
# Importing the dataset
filename = '../Data/reviews_original.csv'
data = pd.read_csv(filename)
#join on id and listing id

data = pd.DataFrame.drop(data, columns=[
    'id',
    'date',
    'reviewer_id',
    'reviewer_name'


])
def calculate_sentiment(entry):
    if (type(entry) != str and math.isnan(entry)):
        return -55
    opinion = TextBlob(entry)
    return opinion.sentiment.polarity


data['comments'] = data['comments'].apply(calculate_sentiment)
data = data[data['comments'] != -55]
data = data.groupby('listing_id')['comments']. mean()
data.to_csv('../Data/reviews_cleaned.csv')
